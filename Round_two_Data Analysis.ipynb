# %% [markdown]
# #### Question 1: The above is data for prebid auctions. There are bidders who receive requests for placing ads, they respond to these requests with a bid and the highest bid wins the auction. Analyse the dataset to answer which bidder has the highest win rate (wins / total_bid).

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\hi\Downloads\analysis.csv")

# %%
df.drop("Unnamed: 0",axis=1,inplace=True)

# %%
df
# Out:
#                 date_hour     client device_type         time_zone  os_name  \
# 0     2021-04-11T01:00:00  asc126828     Desktop   America/Chicago    Linux
# 1     2021-04-11T01:00:00  asc126828     Desktop   America/Chicago    Linux
# 2     2021-04-11T01:00:00  asc126828     Desktop   America/Chicago    Linux
# 3     2021-04-11T01:00:00  asc126828     Desktop   America/Chicago    Linux
# 4     2021-04-11T01:00:00  asc126828     Desktop   America/Chicago    Linux
# ...                   ...        ...         ...               ...      ...
# 4995  2021-04-11T01:00:00  asc126828     Desktop  America/New_York  Windows
# 4996  2021-04-11T01:00:00  asc126828     Desktop  America/New_York  Windows
# 4997  2021-04-11T01:00:00  asc126828     Desktop  America/New_York  Windows
# 4998  2021-04-11T01:00:00  asc126828     Desktop  America/New_York  Windows
# 4999  2021-04-11T01:00:00  asc126828     Desktop  America/New_York  Windows
#
# ...

# %%
df.columns
# Out:
# Index(['date_hour', 'client', 'device_type', 'time_zone', 'os_name',
#        'browser_name', 'ad_unit', 'size', 'bidder', 'bid_range', 'media_type',
#        'request_count', 'response_count', 'prebid_win_count', 'win_count',
#        'sum_bid', 'sum_time_to_respond', 'median', 'min_bid', 'max_bid',
#        'avg_bid', 'sum_2nd_highest_bid', 'sum_prebid_winning_bid',
#        'sum_winning_bid', 'sum_nobid', 'sum_timeout'],
#       dtype='object')

# %%
df["prebid_win_count"]=df["prebid_win_count"].fillna(0)

# %%
df
# Out:
#                 date_hour     client device_type         time_zone  os_name  \
# 0     2021-04-11T01:00:00  asc126828     Desktop   America/Chicago    Linux
# 1     2021-04-11T01:00:00  asc126828     Desktop   America/Chicago    Linux
# 2     2021-04-11T01:00:00  asc126828     Desktop   America/Chicago    Linux
# 3     2021-04-11T01:00:00  asc126828     Desktop   America/Chicago    Linux
# 4     2021-04-11T01:00:00  asc126828     Desktop   America/Chicago    Linux
# ...                   ...        ...         ...               ...      ...
# 4995  2021-04-11T01:00:00  asc126828     Desktop  America/New_York  Windows
# 4996  2021-04-11T01:00:00  asc126828     Desktop  America/New_York  Windows
# 4997  2021-04-11T01:00:00  asc126828     Desktop  America/New_York  Windows
# 4998  2021-04-11T01:00:00  asc126828     Desktop  America/New_York  Windows
# 4999  2021-04-11T01:00:00  asc126828     Desktop  America/New_York  Windows
#
# ...

# %%
df["prebid_win_count"].astype('int64')
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4995    0
# 4996    0
# 4997    0
# 4998    0
# 4999    0
# Name: prebid_win_count, Length: 5000, dtype: int64

# %%
df["win_count"]=df["win_count"].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 df["win_count"]=df["win_count"].astype('int64')
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:6662, in NDFrame.astype(self, dtype, copy, errors)
#    6656     results = [
#    6657         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6658     ]
#    6660 else:
#    6661     # else, only a single dtype is given
# -> 6662     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6663     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6664     return res.__finalize__(self, method="astype")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
# ...

# %%
## Analyse the dataset to answer which bidder has the highest win rate (wins / total_bid).
df["win_rate"]=(df["prebid_win_count"]/5000)

# %%
df
# Out:
#                 date_hour     client device_type         time_zone  os_name  \
# 0     2021-04-11T01:00:00  asc126828     Desktop   America/Chicago    Linux
# 1     2021-04-11T01:00:00  asc126828     Desktop   America/Chicago    Linux
# 2     2021-04-11T01:00:00  asc126828     Desktop   America/Chicago    Linux
# 3     2021-04-11T01:00:00  asc126828     Desktop   America/Chicago    Linux
# 4     2021-04-11T01:00:00  asc126828     Desktop   America/Chicago    Linux
# ...                   ...        ...         ...               ...      ...
# 4995  2021-04-11T01:00:00  asc126828     Desktop  America/New_York  Windows
# 4996  2021-04-11T01:00:00  asc126828     Desktop  America/New_York  Windows
# 4997  2021-04-11T01:00:00  asc126828     Desktop  America/New_York  Windows
# 4998  2021-04-11T01:00:00  asc126828     Desktop  America/New_York  Windows
# 4999  2021-04-11T01:00:00  asc126828     Desktop  America/New_York  Windows
#
# ...

# %%
df["win_rate_percent"]=df["win_rate"]*100

# %%
win=df[df["win_rate_percent"]!=0]

# %%
win["win_rate_percent"].max()
# Out:
# np.float64(2.88)

# %%
win[win["win_rate_percent"]==2.0]
# Out:
#                 date_hour     client device_type         time_zone  os_name  \
# 1236  2021-04-11T01:00:00  asc126828     Desktop  America/New_York  Windows
#
#             browser_name                       ad_unit    size  bidder  \
# 1236  Chrome-89.04389114  div-gpt-ad-BT-D-Responsive-T  728x90  criteo
#
#      bid_range  ...   min_bid   max_bid   avg_bid  sum_2nd_highest_bid  \
# 1236     0-0.1  ...  0.011651  0.099264  0.039769                  NaN
#
#       sum_prebid_winning_bid  sum_winning_bid  sum_nobid  sum_timeout  \
# 1236                3.220282              NaN        NaN          NaN
#
#       win_rate  win_rate_percent
# 1236      0.02               2.0
#
# [1 rows x 28 columns]

# %%
win.drop(2528,axis=0,inplace=True)
# Out:
# C:\Users\hi\AppData\Local\Temp\ipykernel_8464\3661055506.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   win.drop(2528,axis=0,inplace=True)

# %%
 high=win.groupby(["bidder","win_rate_percent"]).max()

# %%
high
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 high[0]
#
# ...

# %%
df
# Out:
#                 date_hour     client device_type         time_zone  os_name  \
# 0     2021-04-11T01:00:00  asc126828     Desktop   America/Chicago    Linux
# 1     2021-04-11T01:00:00  asc126828     Desktop   America/Chicago    Linux
# 2     2021-04-11T01:00:00  asc126828     Desktop   America/Chicago    Linux
# 3     2021-04-11T01:00:00  asc126828     Desktop   America/Chicago    Linux
# 4     2021-04-11T01:00:00  asc126828     Desktop   America/Chicago    Linux
# ...                   ...        ...         ...               ...      ...
# 4995  2021-04-11T01:00:00  asc126828     Desktop  America/New_York  Windows
# 4996  2021-04-11T01:00:00  asc126828     Desktop  America/New_York  Windows
# 4997  2021-04-11T01:00:00  asc126828     Desktop  America/New_York  Windows
# 4998  2021-04-11T01:00:00  asc126828     Desktop  America/New_York  Windows
# 4999  2021-04-11T01:00:00  asc126828     Desktop  America/New_York  Windows
#
# ...

# %%
win_notequal=df[df["prebid_win_count"]!=0]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 win_notequal.groupby(win_notequal["prebid_win_count"].sum(),"bidder",axis=1)
#
# TypeError: DataFrame.groupby() got multiple values for argument 'axis'

# %%
win_rate_df = df.groupby('bidder').agg(
    total_bids=('total_bids', 'sum'),
    wins=('wins', 'sum')
).reset_index()

# %%
win_rate_df['win_rate'] = win_rate_df['wins'] / win_rate_df['total_bids']

# %%
win_notequal["prebid_win_count"].sum()

# %%
win_rate_df = win_rate_df.sort_values(by='win_rate', ascending=False)

# %%
df['total_bids'] = df['response_count']

# %%
win_notequal.groupby(win_notequal["prebid_win_count"].sum(),"bidder").axis
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     576             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     577         except KeyError:
# --> 578             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 'bidder'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8464\1581289184.py in ?()
# ----> 1 win_notequal.groupby(win_notequal["prebid_win_count"].sum(),"bidder").axis
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9163         observed: bool | lib.NoDefault = lib.no_default,
# ...

# %%
win_rate_df = win_rate_df.sort_values(by='win_rate', ascending=False)

# %% [markdown]
# ### undertone has the highest Bid with 0.50
# ### Teads has the  2nd highest bid with 0.46

# %% [markdown]
# ##### Teads has the highesty bid with 2.88%
# ##### criteo has the 2nd Bid with 2.0%
